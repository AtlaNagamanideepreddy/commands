# %% [markdown]
# <a href="https://colab.research.google.com/github/AtlaNagamanideepreddy/commands/blob/main/gen1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-genai

# %%
from google import genai
from google.genai import types

# %%
from google import genai

# Only run this block for Gemini Developer API
client = genai.Client(api_key='AIzaSyBuAT5WSvkvzbJuC_qd4R1vGHwMQqxUvg0')

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents= 'Why is the sky blue?')

# %%
print(response.text)
# Out:
# The reason the sky appears blue is due to a phenomenon called **Rayleigh scattering**, combined with the properties of sunlight and Earth's atmosphere.
#
# Here's a breakdown:
#
# 1.  **Sunlight is White Light (All Colors):**
#     Sunlight, which appears white to us, is actually a mixture of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, violet). We can see this when light passes through a prism or when a rainbow forms. Each color has a different **wavelength** – blue and violet light have shorter, smaller wavelengths, while red and orange light have longer, larger wavelengths.
#
# 2.  **Earth's Atmosphere:**
#     Our planet is surrounded by an atmosphere composed primarily of tiny gas molecules, mainly nitrogen (about 78%) and oxygen (about 21%), along with other trace gases and microscopic particles.
#
# 3.  **The Phenomenon: Scattering:**
# ...
